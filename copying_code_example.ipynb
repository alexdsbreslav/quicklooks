# %%
import quicklook

# %%
chart_skeleton = quicklook.build_chart_skeleton(style = 'default', size = 'default',
title = '',
xlabel = '',
ylabel = '',
x_min_max = (0,1), y_min_max = (0,1),
xtick_interval = 0.25, ytick_interval = 0.25,
horizontal_gridlines_on = False,
vertical_gridlines_on = False);

# %%
chart_skeleton = quicklook.build_chart_skeleton(style = 'default', size = 'default',
title = 'Chart Skeleton Example',
xlabel = 'X-Axis Label',
ylabel = 'Y-Axis\nLabel',
x_min_max = (0,1), y_min_max = (0,1),
xtick_interval = 0.25, ytick_interval = 0.25,
horizontal_gridlines_on = False,
vertical_gridlines_on = False);

# %%
chart_skeleton = quicklook.build_chart_skeleton(style = 'default', size = 'default',
title = 'Chart Skeleton Example',
xlabel = 'X-Axis Label',
ylabel = 'Y-Axis\nLabel',
x_min_max = (0,10), y_min_max = (50,100),
xtick_interval = 1, ytick_interval = 1,
horizontal_gridlines_on = False,
vertical_gridlines_on = False);
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-7243c7e2f160> in <module>
#       6 xtick_interval = 1, ytick_interval = 1,
#       7 horizontal_gridlines_on = False,
# ----> 8 vertical_gridlines_on = False);
#
# ~/OneDrive - Duke University/6_coding_projects/quicklook/quicklook/plot_func.py in build_chart_skeleton(style, size, title, ylabel, xlabel, x_min_max, y_min_max, xtick_interval, ytick_interval, horizontal_gridlines_on, vertical_gridlines_on)
#      52
#      53     if ytick_interval > y_min_max[1] or ytick_interval < y_min_max[0]:
# ---> 54         raise Exception('ytick_interval is not properly defined: ' \
#      55                         'ytick_interval should be greater than y_min and less than y_max. \n'
#      56                         'Imagine the y-axis as a number line from y_min to y_max. ytick_interval'
#
# Exception: ytick_interval is not properly defined: ytick_interval should be greater than y_min and less than y_max.
# Imagine the y-axis as a number line from y_min to y_max. ytick_intervalis the increment that you want to mark off on the number line.
# For example, if y_min = 0, y_max = 1, and ytick_interval = 0.25 your y-axiswould have 0, 0.25, 0.5, 0.75, and 1 marked on it.
